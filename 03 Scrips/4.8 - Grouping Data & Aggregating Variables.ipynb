# %% [markdown]
# #  Task 4.8 - Grouping data & aggregating variables

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Data
# Folder path
path = r'C:\Users\jpelc\Documents\01-2023 Instacart Basket Analysis'

# %%
# Importing 'orders_products_merged.pkl' via pandas.pkl and os.path.join
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update.pkl'))

# %%
# Checking dataframe
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [markdown]
# ### 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe

# %%
# Calulating the mean orders per department
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# The whote dataset has more departments, and the numbers per department are much higher. The mean is higher with the whole database being analyzed.

# %% [markdown]
# ### 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# creating “max_order” column using transform()
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
# Creating a 'loyalty' flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking value counts
df_ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Checking specified columns
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(30)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# ### 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers

# %%
# descriptive statistics for the loyalty_flag
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# There seems to be some differences between the types of customers. The Loyal customers wich are the ones with over 40 orders made, seem to be spending less on there orders. While the Regular customers, those with uner 40 orders, but over 10, are spending the most, and avg. higher order purchases than Loyal customers. And the New customers that have less than 10 orders have the highest avg per order of the group.

# %%
df_ords_prods_merge[df_ords_prods_merge["prices"]> 50.0]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 10030345                 14                     5.0       21553
# 10030346                 16                     4.0       21553
# ...

# %%
# Replace 'prices' value for 'product_id' 21553 with 1.49000 and 'product_id' 33664 with 9.99  
df_ords_prods_merge = df_ords_prods_merge.replace ({"prices":{99999.0: 9.99, 14900.0:1.49 }})

# %%
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                     prices
#                       mean  min   max           sum
# loyalty_flag
# Loyal customer    7.772831  1.0  25.0  7.993651e+07
# New customer      7.800320  1.0  25.0  4.870512e+07
# Regular customer  7.797431  1.0  25.0  1.237981e+08

# %% [markdown]
# After removing the outlining values, the avg price spet by each group is almost the same. Regular customers have a higher sum but is a larger group.

# %% [markdown]
# ### 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# #### 1. If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# #### 2. If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# creating “spending_flag” column using transform()
df_ords_prods_merge['average_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Rounding averages 
df_ords_prods_merge['average_price'] = df_ords_prods_merge['average_price'].round(2)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge    price_range_loc  \
# ...

# %%
# Creating a 'spending_flag' flag
df_ords_prods_merge.loc[df_ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices  _merge    price_range_loc   busiest_day  \
# ...

# %%
# Checking counts
df_ords_prods_merge['spending_flag'].value_counts()
# Out:
# Low spender     32284516
# High spender      120343
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### 1. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### 2. If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### 3. If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# creating “order_frequency_flag” column using transform()
df_ords_prods_merge['median_prior_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge    price_range_loc   busiest_day  busiest_days  \
# ...

# %%
# Creating a 'order_frequency_flag' flag
df_ords_prods_merge.loc[df_ords_prods_merge['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_prior_orders'] > 10) & (df_ords_prods_merge['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...    price_range_loc   busiest_day  busiest_days  \
# ...

# %%
# Checking counts
df_ords_prods_merge['spending_flag'].value_counts()
# Out:
# Low spender     32284516
# High spender      120343
# Name: spending_flag, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
df_ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'average_price', 'spending_flag', 'median_prior_orders',
#        'order_frequency_flag'],
#       dtype='object')

# %%
# Export as PKL
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_merged_grouped.pkl'))
